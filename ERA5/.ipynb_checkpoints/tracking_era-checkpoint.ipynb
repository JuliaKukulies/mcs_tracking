# %% [markdown]
# # Example for tobac application: Tracking of meso-scale precipitation features in ERA 5
#
#
# This example notebook demonstrates the use of tobac to track features of contiguous precipitation areas at meso-scale (~100 km horizontal dimension) for the reanalysis dataset ERA 5.

# %% [markdown]
# **Import necessary python libraries:**

# %%
# Import libraries
import iris
import numpy as np
import pandas as pd
import os,sys
import matplotlib.pyplot as plt
import iris.plot as iplt
import iris.quickplot as qplt
import datetime
import urllib,zipfile,shutil
from netCDF4 import Dataset
import glob
# %matplotlib inline

# %%
# Import tobac itself
import tobac
from tobac import utils

# %%
# Disable a few warnings:
import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)
warnings.filterwarnings('ignore', category=RuntimeWarning, append=True)
warnings.filterwarnings('ignore', category=FutureWarning, append=True)
warnings.filterwarnings('ignore',category=pd.io.pytables.PerformanceWarning)

# %%
# define output directory
data_dir='/media/juli/Elements/ERA5/monthly/'
# variable name in netCDF file 
param= "Total precipitation"

# %% [markdown]
# ## Data preparation
#
# Aggregation into monthly files for each year and setting time axis and calendar, in order to use the downloaded netCDF files with tobac.

# %%
#Set up directory to save output and plots:
import os
savedir=data_dir + 'Save'
os.makedirs(savedir,exist_ok=True)
plotdir=data_dir + 'Plot'
os.makedirs(plotdir,exist_ok=True)

# %% [markdown]
# # Define parameters for feature detection, segmentation and tracking

# %% [markdown]
# ## Feature detection

# %%
# Dictionary containing keyword options (could also be directly given to the function)
parameters_features={}
parameters_features['position_threshold']='weighted_diff' # diff between specific value and threshold for weighting when finding the center location (instead of just mean lon/lat)
parameters_features['min_num']=3 #? 
parameters_features['min_distance']=0 # minimum distance between features 

parameters_features['sigma_threshold']=0.5 # for slightly smoothing (gaussian filter)
parameters_features['n_erosion_threshold']=0 # pixel erosion (for more robust results)

parameters_features['threshold']=[1,2,3,4,5,7,10,15] #mm/h, step-wise threshold for feature detection 
parameters_features['n_min_threshold']=5 # minimum nr of contiguous pixels for thresholds, 10 pixels = ca. 2000 km2

# %% [markdown]
# ## Segmentation

# %%
# Dictionary containing keyword arguments for segmentation step:
parameters_segmentation={}
parameters_segmentation['method']='watershed'
parameters_segmentation['threshold']=1  # mm/h mixing ratio (until which threshold the area is taken into account)

# %% [markdown]
# ## Tracking

# %%
dxy,dt=tobac.get_spacings(Precip)
# Out:
# Available coordinates:     ['time', 'latitude', 'longitude']

# %%
dxy = 36000

# %%
# read in one test file and define spacing 
data_file= data_dir + '/era_precip_tobac_input_200606.nc'
#data_file= data_dir + '/timmean.nc'
Precip=iris.load_cube(data_file, "Total precipitation")
Precip.attributes = None
#display(Precip)
#dxy,dt=tobac.get_spacings(Precip)
Precip.coords('time')
#dt = 60*60 
#dxy = 36000
# Out:
# [DimCoord(array([    0.,    60.,   120.,   180.,   240.,   300.,   360.,   420.,
#           480.,   540.,   600.,   660.,   720.,   780.,   840.,   900.,
#           960.,  1020.,  1080.,  1140.,  1200.,  1260.,  1320.,  1380.,
#          1440.,  1500.,  1560.,  1620.,  1680.,  1740.,  1800.,  1860.,
#          1920.,  1980.,  2040.,  2100.,  2160.,  2220.,  2280.,  2340.,
#          2400.,  2460.,  2520.,  2580.,  2640.,  2700.,  2760.,  2820.,
#          2880.,  2940.,  3000.,  3060.,  3120.,  3180.,  3240.,  3300.,
# %%
# Dictionary containing keyword arguments for the linking step:
parameters_linking={}
parameters_linking['adaptive_stop']=0.2
parameters_linking['adaptive_step']=0.95
parameters_linking['extrapolate']=0
parameters_linking['order']=1
parameters_linking['subnetwork_size']= 1000 # maximum size of subnetwork used for linking 
parameters_linking['memory']=0
parameters_linking['time_cell_min']= dt* 3
parameters_linking['method_linking']='predict'
parameters_linking['v_max']= 10
parameters_linking['d_min']=4*dxy # four times the grid spacing

# %% [markdown]
# # Perform feature detection and segmentation with monthly data chunks

# %%
# get list with all files by month
import glob
file_list= glob.glob(data_dir + '/*tobac_input*.nc')  
print('files in dataset:  ', len(file_list))
file_list.sort()

# %%
Features.to_hdf(os.path.join('/media/juli/Elements/ERA5/monthly/Save/Features_merged.h5'),'table')

# %%
for file in file_list:
    i = file[57:63]
    print('start process for file.....', file)
    ## DATA PREPARATION
    Precip=iris.load_cube(file, param)
    Precip.attributes= None 
    Precip.data *= 1000
    #dxy,dt=tobac.get_spacings(Precip)
    
    # FEATURE DETECTION
    print('starting feature detection based on multiple thresholds')
    Features=tobac.feature_detection_multithreshold(Precip,dxy,**parameters_features)
    print('feature detection done')
    Features.to_hdf(os.path.join(savedir,'Features' + str(i) + '.h5'),'table')
    print('features saved')
    
    # SEGMENTATION 
    print('Starting segmentation based on surface precipitation')
    Mask,Features_Precip=tobac.segmentation_2D(Features,Precip,dxy,**parameters_segmentation)
    print('segmentation based on surface precipitation performed, start saving results to files')
    iris.save([Mask],os.path.join(savedir,'Mask_Segmentation_precip' + str(i) + '.nc'),zlib=True,complevel=4)                
    Features_Precip.to_hdf(os.path.join(savedir,'Features_Precip' + str(i) + '.h5'),'table')
    print('segmentation surface precipitation performed and saved')

# %% [markdown]
# # Trajectory linking

# %%
# read in HDF5 files with saved features
file_list= glob.glob(savedir  + '/Features_Precip??????.h5')  
file_list.sort()
print('nr. of monthly feature files:', len(file_list))
# Out:
# nr. of monthly feature files: 120

# %%
for file in file_list:
    date= file[len(file)-9: len(file)-3]
    ds = Dataset(savedir+ '/Mask_Segmentation_precip'+date+'.nc')
    mask = np.array(ds['segmentation_mask'])  
    print(date, np.shape(mask))
# Out:
# 200601 (744, 81, 141)
# 200602 (672, 81, 141)
# 200603 (744, 81, 141)
# 200604 (720, 81, 141)
# 200605 (744, 81, 141)
# 200606 (720, 81, 141)
# 200607 (744, 81, 141)
# 200608 (744, 81, 141)
# 200609 (720, 81, 141)
# 200610 (744, 81, 141)
# 200611 (720, 81, 141)
# 200612 (744, 81, 141)
# 200701 (744, 81, 141)
# 200702 (672, 81, 141)
# 200703 (744, 81, 141)
# 200704 (720, 81, 141)
# 200705 (744, 81, 141)
# 200706 (720, 81, 141)
# 200707 (744, 81, 141)
# 200708 (744, 81, 141)
# 200709 (720, 81, 141)
# 200710 (744, 81, 141)
# 200711 (720, 81, 141)
# 200712 (744, 81, 141)
# 200901 (744, 81, 141)
# 200902 (672, 81, 141)
# 200903 (744, 81, 141)
# 200904 (720, 81, 141)
        date= file[len(file)-9: len(file)-3]
        ds = Dataset(savedir+ '/Mask_Segmentation_precip'+date+'.nc')
        mask = np.array(ds['segmentation_mask'])  
        # update total nr of frames 
        frames += np.shape(mask)[0] -1
        i += 1 
        print('file for: ',date, 'rows: ',Features.shape[0], 'frames: ', frames)

    else:
        features = pd.read_hdf(file, 'table')
        # update frame number and make sure they are sequential
        features['frame'] = features['frame']  + frames
        # append dataframes 
        Features = Features.append(features, ignore_index=True)      
        # read in data mask with segments for tracked cells 
        date= file[len(file)-9: len(file)-3]
        ds = Dataset(savedir+ '/Mask_Segmentation_precip'+date+'.nc')
        mask = np.array(ds['segmentation_mask'])  
        #update total nr of frames
        frames += np.shape(mask)[0] 
        print('file for: ',date, 'rows: ',np.shape(mask)[0] , 'frames: ', frames)
# Out:
# file for:  200601 rows:  585 frames:  743
# file for:  200602 rows:  672 frames:  1415
# file for:  200603 rows:  744 frames:  2159
# file for:  200604 rows:  720 frames:  2879
# file for:  200605 rows:  744 frames:  3623
# file for:  200606 rows:  720 frames:  4343
# file for:  200607 rows:  744 frames:  5087
# file for:  200608 rows:  744 frames:  5831
# file for:  200609 rows:  720 frames:  6551
# file for:  200610 rows:  744 frames:  7295
# file for:  200611 rows:  720 frames:  8015
# file for:  200612 rows:  744 frames:  8759
# file for:  200701 rows:  744 frames:  9503
# file for:  200702 rows:  672 frames:  10175
# file for:  200703 rows:  744 frames:  10919
# file for:  200704 rows:  720 frames:  11639
# file for:  200705 rows:  744 frames:  12383
# file for:  200706 rows:  720 frames:  13103
# file for:  200707 rows:  744 frames:  13847
# file for:  200708 rows:  744 frames:  14591
# file for:  200709 rows:  720 frames:  15311
# file for:  200710 rows:  744 frames:  16055
# file for:  200711 rows:  720 frames:  16775
# file for:  200712 rows:  744 frames:  17519
# file for:  200901 rows:  744 frames:  18263
# file for:  200902 rows:  672 frames:  18935
# file for:  200903 rows:  744 frames:  19679
# file for:  200904 rows:  720 frames:  20399
# file for:  200905 rows:  744 frames:  21143
# file for:  200906 rows:  720 frames:  21863
# file for:  200907 rows:  744 frames:  22607
# file for:  200908 rows:  744 frames:  23351
# file for:  200909 rows:  720 frames:  24071
# file for:  200910 rows:  744 frames:  24815
# file for:  200911 rows:  720 frames:  25535
# file for:  200912 rows:  744 frames:  26279
# file for:  201001 rows:  744 frames:  27023
# file for:  201002 rows:  672 frames:  27695
# file for:  201003 rows:  744 frames:  28439
# file for:  201004 rows:  720 frames:  29159
# file for:  201005 rows:  744 frames:  29903
# file for:  201006 rows:  720 frames:  30623
# file for:  201007 rows:  744 frames:  31367
# file for:  201008 rows:  744 frames:  32111
# file for:  201009 rows:  720 frames:  32831
# file for:  201010 rows:  744 frames:  33575
# file for:  201011 rows:  720 frames:  34295
# file for:  201012 rows:  744 frames:  35039
# file for:  201101 rows:  744 frames:  35783
# file for:  201102 rows:  672 frames:  36455
# file for:  201103 rows:  744 frames:  37199
# file for:  201104 rows:  720 frames:  37919
# file for:  201105 rows:  744 frames:  38663

# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-135-5d1de7a0ed7b> in <module>
# ----> 1 Track=tobac.linking_trackpy(Features,Precip,dt=dt,dxy=dxy,**parameters_linking)
#       2 # remove NaN tracks from feature space!
#       3 Track = Tracks.loc[Tracks.cell > 0]
#       4 Track.to_hdf(os.path.join(savedir,'Tracks_ERA5_2006_2016_storms.h5'),'table')
#
# NameError: name 'parameters_linking' is not defined

# %% [markdown]
# # Some examples for analysis and visualisation...

# %%
## SEGMENT SELECTION 

# This function takes a time slot of the cell mask (with tracked features) and a feature ID as an input and returns an index
# marking the entire region which belongs to cell in the specific timestep (this is needed), since
# the segmentation and cell masks still contain different feature IDs for one cloud object whereas
# only one feature is listed in the tracking dataframe

def select_segment(mask, f):
    import scipy.ndimage as ndi
    # labeling : each contiguous region is associated with an int
    labels, n = ndi.label(mask)
    x = np.where(mask== f)[0][0]
    y= np.where(mask == f)[1][0]
    new_label = labels[x,y]
    segment_i = labels == new_label

    return segment_i

# %%
def get_rainrates(f, Tracks, path, frames ,it):
    from netCDF4 import Dataset
    date= f[len(f)-9: len(f)-3]
    yearmonth= f[len(f)-9: len(f)-5] + '-' + f[len(f)-5: len(f)-3]
    print('get rain rates for.....', date)

    # read in cell mask 
    ds = Dataset(f)
    mask = np.array(ds['__xarray_dataarray_variable__'])  
    
    file = glob.glob(path + 'era_precip_*tobac*'+ date + '.nc')[0]
    ds_precip= Dataset(file)
    precip = np.array(ds_precip['tp'])*1000
    precip[precip < 0.0 ] = 0 
    ds_precip.close()
    
    # select features for corresponding month in combined tracks 
    feat_select= Tracks.loc[Tracks['timestr'].dt.strftime('%Y-%m') == yearmonth]
    
    for frame, values in enumerate(mask):
        frame_idx_table = frame + feat_select['frame'].values[0]
        frame_select =feat_select.loc[feat_select['frame'] == frame_idx_table]  # all tracked features in this time frame 
        frame_idx_mask= frame_idx_table  - frames  
            
        if frame_idx_mask < 0 :
            print('error in mask index calculation! --->', frame_idx_mask)
            break
        if frame_select.shape[0] != 0 and frame_idx_mask < np.shape(mask)[0]: 
            
            features= mask[frame_idx_mask, :, :] # specific frame with tracked features
            precip_frame = precip[frame_idx_mask, :,:] # specific frame with rain rates 
            
            # extract max and mean rain rates 
            for f in np.unique(features[features > 0]):
                segment_i = select_segment(features, f )
                max_prec = np.nanmax(precip_frame[segment_i])
                mean_prec = np.nanmean(precip_frame[segment_i])   
                total_precip = np.nansum(precip_frame[segment_i])
                area = np.shape(precip_frame[segment_i])[0]*dxy*dxy 
                eq_radius = np.sqrt(area/np.pi)
                
                # add values to track dataframe 
                for i in Tracks[Tracks['feature'] == f ].index:
                    Tracks.at[i, 'total_precip']= total_precip
                    Tracks.at[i, 'max_rr']= max_prec
                    Tracks.at[i, 'mean_rr']= mean_prec
                    Tracks.at[i, 'area']= area
                    Tracks.at[i, 'eq_rad']= eq_radius 

    print('dataframe update for all features in ',str(yearmonth), 'frames:', frames, 'mask', np.shape(mask))
    if it == 0:
        frames += np.shape(mask)[0] - 1 
        it = 1 
    else:
        frames += np.shape(mask)[0]
        
    return Tracks, frames, it

# %%
# import tracks for ERA 
import pandas as pd
savedir='/media/juli/Elements/ERA5/monthly/Save'
file = savedir + '/Tracks_ERA5_2006_2016_new.h5'
Tracks_era = pd.read_hdf(file, 'table')
Tracks_era['timestr']=pd.to_datetime(Tracks_era['timestr'],format='%Y-%m-%d %H:%M:%S')

# %%
mcs.to_hdf(savedir + '/track_statistics_era5.h5','table')

# %%
Tracks.to_hdf(savedir + '/Tracks_ERA5_2006-2016_storms_v.h5','table')

# %%
# RAIN STATS
import glob
data_dir = '/media/juli/Elements/ERA5/monthly/'
# cell masks
file_list= glob.glob(savedir  + '/Precip_cells??????.nc')  
file_list.sort()

# add new column 
Tracks  = Tracks.reindex( columns = Tracks.columns.tolist() + ['total_precip']) 
Tracks  = Tracks.reindex( columns = Tracks.columns.tolist() + ['max_rr']) 
Tracks  = Tracks.reindex( columns = Tracks.columns.tolist() + ['mean_rr']) 
Tracks  = Tracks.reindex( columns = Tracks.columns.tolist() + ['area']) 
Tracks  = Tracks.reindex( columns = Tracks.columns.tolist() + ['eq_rad'])

# %%
frames = 0 
it = 0 
path = data_dir
for f in file_list:
    Tracks, frames, it = get_rainrates(f, Tracks, path, frames, it )
# Out:
# get rain rates for..... 200601
# dataframe update for all features in  2006-01 frames: 0 mask (744, 81, 141)
# get rain rates for..... 200602
# dataframe update for all features in  2006-02 frames: 743 mask (672, 81, 141)
# get rain rates for..... 200603
# dataframe update for all features in  2006-03 frames: 1415 mask (744, 81, 141)
# get rain rates for..... 200604
# dataframe update for all features in  2006-04 frames: 2159 mask (720, 81, 141)
# get rain rates for..... 200605
# dataframe update for all features in  2006-05 frames: 2879 mask (744, 81, 141)
# get rain rates for..... 200606
# dataframe update for all features in  2006-06 frames: 3623 mask (720, 81, 141)
# get rain rates for..... 200607
# dataframe update for all features in  2006-07 frames: 4343 mask (744, 81, 141)
# get rain rates for..... 200608
# dataframe update for all features in  2006-08 frames: 5087 mask (744, 81, 141)
# get rain rates for..... 200609
# dataframe update for all features in  2006-09 frames: 5831 mask (720, 81, 141)
# get rain rates for..... 200610
# dataframe update for all features in  2006-10 frames: 6551 mask (744, 81, 141)
# get rain rates for..... 200611
# dataframe update for all features in  2006-11 frames: 7295 mask (720, 81, 141)
# get rain rates for..... 200612
# dataframe update for all features in  2006-12 frames: 8015 mask (744, 81, 141)
# get rain rates for..... 200701
# dataframe update for all features in  2007-01 frames: 8759 mask (744, 81, 141)
# get rain rates for..... 200702
# dataframe update for all features in  2007-02 frames: 9503 mask (672, 81, 141)
# get rain rates for..... 200703
# dataframe update for all features in  2007-03 frames: 10175 mask (744, 81, 141)
# get rain rates for..... 200704
# dataframe update for all features in  2007-04 frames: 10919 mask (720, 81, 141)
# get rain rates for..... 200705
# dataframe update for all features in  2007-05 frames: 11639 mask (744, 81, 141)
# get rain rates for..... 200706
# dataframe update for all features in  2007-06 frames: 12383 mask (720, 81, 141)
# get rain rates for..... 201606
# dataframe update for all features in  2016-06 frames: 82511 mask (720, 81, 141)
# get rain rates for..... 201607
# dataframe update for all features in  2016-07 frames: 83231 mask (744, 81, 141)
# get rain rates for..... 201608
# dataframe update for all features in  2016-08 frames: 83975 mask (744, 81, 141)
# get rain rates for..... 201609
# dataframe update for all features in  2016-09 frames: 84719 mask (720, 81, 141)
# get rain rates for..... 201610
# dataframe update for all features in  2016-10 frames: 85439 mask (744, 81, 141)
# get rain rates for..... 201611
# dataframe update for all features in  2016-11 frames: 86183 mask (720, 81, 141)
# get rain rates for..... 201612
# dataframe update for all features in  2016-12 frames: 86903 mask (744, 81, 141)

# %%
## create a new dataframe for tracked cells, which are possible mesoscale convective system candidates

# dataframe to store system stats 
mcs = pd.DataFrame(columns=['id', 'init_time', 'total_precip','mean_rr', 'max_rr' ,'lifetime', 'v' , 'max_area', 'mean_area','total_area', 'features>5mm', 'TP_flag'])

for idx, cell in Tracks.groupby('cell'):
    # compute statistics 
    cell_id = cell.cell.values[0]
    init_time = cell.time.values[0]
    total_precip = np.nansum(cell.total_precip.values)*0.5
    mean_rr = np.nanmean(cell.mean_rr.values)
    max_rr= np.nanmax(cell.max_rr.values)
    lifetime = np.shape(cell)[0]*0.5
    v= np.nanmean(cell.v.values)
    mean_area = np.nanmean(cell.area.values)
    max_area = np.nanmax(cell.area.values)
    total_area = np.nansum(cell.area.values) 
    features_5 = np.shape(cell.threshold_value.values[cell.threshold_value.values >= 5])[0]
    flag = 999
    # add flag in order to mark whether the precip system lies within the 3000 boundary or not 
    #if np.nansum(cell.flag.values) == 0:
     #   flag = 0 
    #elif np.nansum(cell.flag.values) >= np.shape(cell)[0]*2 - 4:
     #   flag = 2 
    #else:
     #   flag = 1 

    # add to dataframe 
    data = [int(cell_id), str(init_time), float(total_precip),float(mean_rr), float(max_rr), float(lifetime), float(v), float(mean_area), float(max_area), float(total_area), float(features_5), int(flag)]
    mcs.loc[len(mcs)]= data
    print('dataframe updated for cell', cell_id)
# Out:
# dataframe updated for cell 1.0
# dataframe updated for cell 2.0
# dataframe updated for cell 5.0
# dataframe updated for cell 12.0
# dataframe updated for cell 14.0
# dataframe updated for cell 15.0
# dataframe updated for cell 17.0
# dataframe updated for cell 18.0
# dataframe updated for cell 19.0
# dataframe updated for cell 20.0
# dataframe updated for cell 22.0
# dataframe updated for cell 27.0
# dataframe updated for cell 28.0
# dataframe updated for cell 31.0
# dataframe updated for cell 32.0
# dataframe updated for cell 34.0
# dataframe updated for cell 37.0
# dataframe updated for cell 44.0
# dataframe updated for cell 51.0
# dataframe updated for cell 57.0
# dataframe updated for cell 58.0
# dataframe updated for cell 65.0
# dataframe updated for cell 67.0
# dataframe updated for cell 70.0
# dataframe updated for cell 72.0
# dataframe updated for cell 73.0
# dataframe updated for cell 74.0
# dataframe updated for cell 76.0
# dataframe updated for cell 79.0
# dataframe updated for cell 80.0
# dataframe updated for cell 82.0
# dataframe updated for cell 84.0
# dataframe updated for cell 85.0
# dataframe updated for cell 87.0
# dataframe updated for cell 92.0
# dataframe updated for cell 94.0
# dataframe updated for cell 96.0
# dataframe updated for cell 101.0
# dataframe updated for cell 110.0
# dataframe updated for cell 116.0
# dataframe updated for cell 117.0
# dataframe updated for cell 118.0
# dataframe updated for cell 124.0
# dataframe updated for cell 126.0
# dataframe updated for cell 131.0
# dataframe updated for cell 133.0
# dataframe updated for cell 134.0
# dataframe updated for cell 139.0
# dataframe updated for cell 140.0
# dataframe updated for cell 143.0
# dataframe updated for cell 150.0
# dataframe updated for cell 151.0
# dataframe updated for cell 158.0
# dataframe updated for cell 163.0
# dataframe updated for cell 164.0
# dataframe updated for cell 171.0
# dataframe updated for cell 176.0
# dataframe updated for cell 177.0
# dataframe updated for cell 178.0
# dataframe updated for cell 182.0
# dataframe updated for cell 186.0
# dataframe updated for cell 187.0
# dataframe updated for cell 188.0
# dataframe updated for cell 190.0
# dataframe updated for cell 197.0
# dataframe updated for cell 200.0
# dataframe updated for cell 204.0
# dataframe updated for cell 206.0
# dataframe updated for cell 211.0
# dataframe updated for cell 224.0
# dataframe updated for cell 225.0
# dataframe updated for cell 226.0
# dataframe updated for cell 227.0
# dataframe updated for cell 232.0
# dataframe updated for cell 233.0
# dataframe updated for cell 235.0
# dataframe updated for cell 237.0
# dataframe updated for cell 245.0
# dataframe updated for cell 249.0
# dataframe updated for cell 252.0
# dataframe updated for cell 254.0
# dataframe updated for cell 255.0
# dataframe updated for cell 257.0
# dataframe updated for cell 261.0
# dataframe updated for cell 262.0
# dataframe updated for cell 264.0
# dataframe updated for cell 267.0
# dataframe updated for cell 269.0
# dataframe updated for cell 270.0
# dataframe updated for cell 275.0
# dataframe updated for cell 276.0
# dataframe updated for cell 278.0
# dataframe updated for cell 279.0
# dataframe updated for cell 284.0
# dataframe updated for cell 286.0
# dataframe updated for cell 287.0
# dataframe updated for cell 291.0
# dataframe updated for cell 292.0
# dataframe updated for cell 294.0
# dataframe updated for cell 296.0
# dataframe updated for cell 297.0
# dataframe updated for cell 299.0
# dataframe updated for cell 300.0
# dataframe updated for cell 304.0
# dataframe updated for cell 308.0
# dataframe updated for cell 309.0
# dataframe updated for cell 310.0
# dataframe updated for cell 318.0
# dataframe updated for cell 322.0
# dataframe updated for cell 326.0
# dataframe updated for cell 329.0
# dataframe updated for cell 330.0
# dataframe updated for cell 335.0
# dataframe updated for cell 336.0
# dataframe updated for cell 337.0
# dataframe updated for cell 343.0
# dataframe updated for cell 346.0
# dataframe updated for cell 347.0
# dataframe updated for cell 352.0
# dataframe updated for cell 353.0
# dataframe updated for cell 359.0
# dataframe updated for cell 363.0
# dataframe updated for cell 366.0
# dataframe updated for cell 371.0
# dataframe updated for cell 372.0
# dataframe updated for cell 375.0
# dataframe updated for cell 377.0
# dataframe updated for cell 379.0
# dataframe updated for cell 380.0
# dataframe updated for cell 388.0
# dataframe updated for cell 393.0
# dataframe updated for cell 397.0
# dataframe updated for cell 398.0
# dataframe updated for cell 399.0
# dataframe updated for cell 402.0
# dataframe updated for cell 403.0
# dataframe updated for cell 407.0
# dataframe updated for cell 409.0
# dataframe updated for cell 410.0
# dataframe updated for cell 413.0
# dataframe updated for cell 417.0
# dataframe updated for cell 418.0
# dataframe updated for cell 419.0
# dataframe updated for cell 420.0
# dataframe updated for cell 423.0
# dataframe updated for cell 428.0
# dataframe updated for cell 429.0
# dataframe updated for cell 430.0
# dataframe updated for cell 434.0
# dataframe updated for cell 435.0
# dataframe updated for cell 438.0
# dataframe updated for cell 439.0
# dataframe updated for cell 446.0
# dataframe updated for cell 447.0
# dataframe updated for cell 451.0
# dataframe updated for cell 457.0
# dataframe updated for cell 459.0
# dataframe updated for cell 461.0
# dataframe updated for cell 462.0
# dataframe updated for cell 463.0
# dataframe updated for cell 467.0
# dataframe updated for cell 469.0
# dataframe updated for cell 476.0
# dataframe updated for cell 477.0
# dataframe updated for cell 478.0
# dataframe updated for cell 480.0
# dataframe updated for cell 482.0
# dataframe updated for cell 485.0
# dataframe updated for cell 486.0
# dataframe updated for cell 487.0
# dataframe updated for cell 494.0
# dataframe updated for cell 497.0
# dataframe updated for cell 499.0
# dataframe updated for cell 500.0
# dataframe updated for cell 502.0
# dataframe updated for cell 504.0
# dataframe updated for cell 507.0
# dataframe updated for cell 508.0
# dataframe updated for cell 511.0
# dataframe updated for cell 512.0
# dataframe updated for cell 522.0
# dataframe updated for cell 524.0
# dataframe updated for cell 525.0
# dataframe updated for cell 530.0
# dataframe updated for cell 532.0
# dataframe updated for cell 533.0
# dataframe updated for cell 535.0
# dataframe updated for cell 536.0
# dataframe updated for cell 546.0
# dataframe updated for cell 547.0
# dataframe updated for cell 554.0
# dataframe updated for cell 557.0
# dataframe updated for cell 560.0
# dataframe updated for cell 564.0
# dataframe updated for cell 571.0
# dataframe updated for cell 575.0
# dataframe updated for cell 582.0
# dataframe updated for cell 584.0
# dataframe updated for cell 585.0
# dataframe updated for cell 586.0
# dataframe updated for cell 590.0
# dataframe updated for cell 592.0
# dataframe updated for cell 593.0
# dataframe updated for cell 594.0
# dataframe updated for cell 597.0
# dataframe updated for cell 599.0
# dataframe updated for cell 600.0
# dataframe updated for cell 609.0
# dataframe updated for cell 621.0
# dataframe updated for cell 628.0
# dataframe updated for cell 632.0
# dataframe updated for cell 641.0
# dataframe updated for cell 643.0
# dataframe updated for cell 645.0
# dataframe updated for cell 646.0
# dataframe updated for cell 648.0
# dataframe updated for cell 649.0
# dataframe updated for cell 653.0
# dataframe updated for cell 655.0
# dataframe updated for cell 660.0
# dataframe updated for cell 662.0
# dataframe updated for cell 683.0
# dataframe updated for cell 692.0
# dataframe updated for cell 697.0
# dataframe updated for cell 703.0
# dataframe updated for cell 705.0
# dataframe updated for cell 706.0
# dataframe updated for cell 725.0
# dataframe updated for cell 726.0
# dataframe updated for cell 728.0
# dataframe updated for cell 731.0
# dataframe updated for cell 734.0
# dataframe updated for cell 735.0
# dataframe updated for cell 738.0
# dataframe updated for cell 740.0
# dataframe updated for cell 744.0
# dataframe updated for cell 748.0
# dataframe updated for cell 751.0
# dataframe updated for cell 761.0
# dataframe updated for cell 766.0
# dataframe updated for cell 767.0
# dataframe updated for cell 768.0
# dataframe updated for cell 771.0
# dataframe updated for cell 773.0
# dataframe updated for cell 777.0
# dataframe updated for cell 786.0
# dataframe updated for cell 800.0
# dataframe updated for cell 805.0
# dataframe updated for cell 810.0
# dataframe updated for cell 812.0
# dataframe updated for cell 815.0
# dataframe updated for cell 816.0
# dataframe updated for cell 818.0
# dataframe updated for cell 840.0
# dataframe updated for cell 845.0
# dataframe updated for cell 854.0
# dataframe updated for cell 857.0
# dataframe updated for cell 863.0
# dataframe updated for cell 867.0
# dataframe updated for cell 868.0
# dataframe updated for cell 871.0
# dataframe updated for cell 874.0
# dataframe updated for cell 879.0
# dataframe updated for cell 884.0
# dataframe updated for cell 885.0
# dataframe updated for cell 886.0
# dataframe updated for cell 887.0
# dataframe updated for cell 889.0
# dataframe updated for cell 890.0
# dataframe updated for cell 892.0
# dataframe updated for cell 897.0
# dataframe updated for cell 901.0
# dataframe updated for cell 906.0
# dataframe updated for cell 909.0
# dataframe updated for cell 917.0
# dataframe updated for cell 924.0
# dataframe updated for cell 925.0
# dataframe updated for cell 928.0
# dataframe updated for cell 937.0
# dataframe updated for cell 938.0
# dataframe updated for cell 942.0
# dataframe updated for cell 953.0
# dataframe updated for cell 956.0
# dataframe updated for cell 959.0
# dataframe updated for cell 966.0
# dataframe updated for cell 979.0
# dataframe updated for cell 983.0
# dataframe updated for cell 984.0
# dataframe updated for cell 985.0
# dataframe updated for cell 986.0
# dataframe updated for cell 988.0
# dataframe updated for cell 991.0
# dataframe updated for cell 994.0
# dataframe updated for cell 997.0
# dataframe updated for cell 1000.0
# dataframe updated for cell 1006.0
# dataframe updated for cell 1008.0
# dataframe updated for cell 1013.0
# dataframe updated for cell 1019.0
# dataframe updated for cell 1023.0
# dataframe updated for cell 1025.0
# dataframe updated for cell 1038.0
# dataframe updated for cell 1040.0
# dataframe updated for cell 1042.0
# dataframe updated for cell 1045.0
# dataframe updated for cell 1048.0
# dataframe updated for cell 1055.0
# dataframe updated for cell 1057.0
# dataframe updated for cell 1058.0
# dataframe updated for cell 1059.0
# dataframe updated for cell 1066.0
# dataframe updated for cell 1070.0
# dataframe updated for cell 1071.0
# dataframe updated for cell 1076.0
# dataframe updated for cell 1077.0
# dataframe updated for cell 1078.0
# dataframe updated for cell 1086.0
# dataframe updated for cell 1088.0
# dataframe updated for cell 1094.0
# dataframe updated for cell 1096.0
# dataframe updated for cell 1098.0
# dataframe updated for cell 1099.0
# dataframe updated for cell 1101.0
# dataframe updated for cell 1102.0
# dataframe updated for cell 1119.0
# dataframe updated for cell 1120.0
# dataframe updated for cell 1124.0
# dataframe updated for cell 1127.0
# dataframe updated for cell 1130.0
# dataframe updated for cell 1137.0
# dataframe updated for cell 1140.0
# dataframe updated for cell 1141.0
# dataframe updated for cell 1142.0
# dataframe updated for cell 1146.0
# dataframe updated for cell 1150.0
# dataframe updated for cell 1151.0
# dataframe updated for cell 2766.0
# dataframe updated for cell 2771.0
# dataframe updated for cell 2772.0
# dataframe updated for cell 2774.0
# dataframe updated for cell 2777.0
# dataframe updated for cell 2783.0
# dataframe updated for cell 2786.0
# dataframe updated for cell 2789.0
# dataframe updated for cell 2790.0
# dataframe updated for cell 2797.0
# dataframe updated for cell 2805.0
# dataframe updated for cell 2811.0
# dataframe updated for cell 2821.0
# dataframe updated for cell 2824.0
# dataframe updated for cell 2826.0
# dataframe updated for cell 2828.0
# dataframe updated for cell 2830.0
# dataframe updated for cell 2832.0
# dataframe updated for cell 2837.0
# dataframe updated for cell 2840.0
# dataframe updated for cell 2846.0
# dataframe updated for cell 2850.0
# dataframe updated for cell 2855.0
# dataframe updated for cell 2861.0
# dataframe updated for cell 2863.0
# dataframe updated for cell 2864.0
# dataframe updated for cell 2866.0
# dataframe updated for cell 2870.0
# dataframe updated for cell 2886.0
# dataframe updated for cell 2891.0
# dataframe updated for cell 2895.0
# dataframe updated for cell 2918.0
# dataframe updated for cell 2931.0
# dataframe updated for cell 2935.0
# dataframe updated for cell 2944.0
# dataframe updated for cell 2961.0
# dataframe updated for cell 2965.0
# dataframe updated for cell 2971.0
# dataframe updated for cell 2974.0
# dataframe updated for cell 2977.0
# dataframe updated for cell 2978.0
# dataframe updated for cell 2984.0
# dataframe updated for cell 2986.0
# dataframe updated for cell 2987.0
# dataframe updated for cell 2992.0
# dataframe updated for cell 3001.0
# dataframe updated for cell 3006.0
# dataframe updated for cell 3007.0
# dataframe updated for cell 3017.0
# dataframe updated for cell 3018.0
# dataframe updated for cell 3019.0
# dataframe updated for cell 3027.0
# dataframe updated for cell 3033.0
# dataframe updated for cell 3036.0
# dataframe updated for cell 3041.0
# dataframe updated for cell 3044.0
# dataframe updated for cell 3045.0
# dataframe updated for cell 3057.0
# dataframe updated for cell 3069.0
# dataframe updated for cell 3074.0
# dataframe updated for cell 3076.0
# dataframe updated for cell 3080.0
# dataframe updated for cell 3084.0
# dataframe updated for cell 3085.0
# dataframe updated for cell 3088.0
# dataframe updated for cell 3089.0
# dataframe updated for cell 3090.0
# dataframe updated for cell 3092.0
# dataframe updated for cell 3094.0
# dataframe updated for cell 3097.0
# dataframe updated for cell 3099.0
# dataframe updated for cell 3125.0
# dataframe updated for cell 3130.0
# dataframe updated for cell 3134.0
# dataframe updated for cell 3140.0
# dataframe updated for cell 3143.0
# dataframe updated for cell 3147.0
# dataframe updated for cell 3148.0
# dataframe updated for cell 3152.0
# dataframe updated for cell 3155.0
# dataframe updated for cell 3161.0
# dataframe updated for cell 3166.0
# dataframe updated for cell 3170.0
# dataframe updated for cell 3171.0
# dataframe updated for cell 3176.0
# dataframe updated for cell 3182.0
# dataframe updated for cell 3183.0
# dataframe updated for cell 3193.0
# dataframe updated for cell 3195.0
# dataframe updated for cell 3202.0
# dataframe updated for cell 3204.0
# dataframe updated for cell 3205.0
# dataframe updated for cell 3206.0
# dataframe updated for cell 3210.0
# dataframe updated for cell 3211.0
# dataframe updated for cell 3720.0
# dataframe updated for cell 3721.0
# dataframe updated for cell 3726.0
# dataframe updated for cell 3727.0
# dataframe updated for cell 3728.0
# dataframe updated for cell 3729.0
# dataframe updated for cell 3730.0
# dataframe updated for cell 3731.0
# dataframe updated for cell 3740.0
# dataframe updated for cell 3741.0
# dataframe updated for cell 3744.0
# dataframe updated for cell 3750.0
# dataframe updated for cell 3751.0
# dataframe updated for cell 3752.0
# dataframe updated for cell 3753.0
# dataframe updated for cell 3754.0
# dataframe updated for cell 3755.0
# dataframe updated for cell 3757.0
# dataframe updated for cell 3763.0
# dataframe updated for cell 3766.0
# dataframe updated for cell 3768.0
# dataframe updated for cell 3769.0
# dataframe updated for cell 3774.0
# dataframe updated for cell 3777.0
# dataframe updated for cell 3779.0
# dataframe updated for cell 3784.0
# dataframe updated for cell 3800.0
# dataframe updated for cell 3809.0
# dataframe updated for cell 3813.0
# dataframe updated for cell 3814.0
# dataframe updated for cell 3820.0
# dataframe updated for cell 3825.0
# dataframe updated for cell 3826.0
# dataframe updated for cell 3833.0
# dataframe updated for cell 3838.0
# dataframe updated for cell 3840.0
# dataframe updated for cell 3844.0
# dataframe updated for cell 3847.0
# dataframe updated for cell 3854.0
# dataframe updated for cell 3855.0
# dataframe updated for cell 3859.0
# dataframe updated for cell 3862.0
# dataframe updated for cell 3867.0
# dataframe updated for cell 3886.0
# dataframe updated for cell 3895.0
# dataframe updated for cell 3901.0
# dataframe updated for cell 3902.0
# dataframe updated for cell 3905.0
# dataframe updated for cell 3909.0
# dataframe updated for cell 3916.0
# dataframe updated for cell 3919.0
# dataframe updated for cell 3923.0
# dataframe updated for cell 3924.0
# dataframe updated for cell 3927.0
# dataframe updated for cell 3929.0
# dataframe updated for cell 3932.0
# dataframe updated for cell 3933.0
# dataframe updated for cell 3941.0
# dataframe updated for cell 3942.0
# dataframe updated for cell 3946.0
# dataframe updated for cell 3947.0
# dataframe updated for cell 3952.0
# dataframe updated for cell 3960.0
# dataframe updated for cell 3967.0
# dataframe updated for cell 3992.0
# dataframe updated for cell 4000.0
# dataframe updated for cell 4003.0
# dataframe updated for cell 4005.0
# dataframe updated for cell 4010.0
# dataframe updated for cell 4011.0
# dataframe updated for cell 4012.0
# dataframe updated for cell 4014.0
# dataframe updated for cell 4023.0
# dataframe updated for cell 4025.0
# dataframe updated for cell 4027.0
# dataframe updated for cell 4032.0
# dataframe updated for cell 4033.0
# dataframe updated for cell 4037.0
# dataframe updated for cell 4050.0
# dataframe updated for cell 4057.0
# dataframe updated for cell 4058.0
# dataframe updated for cell 4070.0
# dataframe updated for cell 4082.0
# dataframe updated for cell 4097.0
# dataframe updated for cell 4099.0
# dataframe updated for cell 4101.0
# dataframe updated for cell 4108.0
# dataframe updated for cell 4114.0
# dataframe updated for cell 4116.0
# dataframe updated for cell 4119.0
# dataframe updated for cell 4124.0
# dataframe updated for cell 4127.0
# dataframe updated for cell 4131.0
# dataframe updated for cell 4136.0
# dataframe updated for cell 4138.0
# dataframe updated for cell 4512.0
# dataframe updated for cell 4515.0
# dataframe updated for cell 4529.0
# dataframe updated for cell 4533.0
# dataframe updated for cell 4535.0
# dataframe updated for cell 4552.0
# dataframe updated for cell 4559.0
# dataframe updated for cell 4566.0
# dataframe updated for cell 4568.0
# dataframe updated for cell 4573.0
# dataframe updated for cell 4576.0
# dataframe updated for cell 4577.0
# dataframe updated for cell 4578.0
# dataframe updated for cell 4584.0
# dataframe updated for cell 4587.0
# dataframe updated for cell 4588.0
# dataframe updated for cell 4590.0
# dataframe updated for cell 4591.0
# dataframe updated for cell 4592.0
# dataframe updated for cell 4593.0
# dataframe updated for cell 4594.0
# dataframe updated for cell 4604.0
# dataframe updated for cell 4607.0
# dataframe updated for cell 4609.0
# dataframe updated for cell 4610.0
# dataframe updated for cell 4611.0
# dataframe updated for cell 4616.0
# dataframe updated for cell 4617.0
# dataframe updated for cell 4620.0
# dataframe updated for cell 4643.0
# dataframe updated for cell 4652.0
# dataframe updated for cell 4656.0
# dataframe updated for cell 4663.0
# dataframe updated for cell 4668.0
# dataframe updated for cell 4673.0
# dataframe updated for cell 4680.0
# dataframe updated for cell 4681.0
# dataframe updated for cell 4688.0
# dataframe updated for cell 4689.0
# dataframe updated for cell 4691.0
# dataframe updated for cell 4693.0
# dataframe updated for cell 4696.0
# dataframe updated for cell 4698.0
# dataframe updated for cell 4700.0
# dataframe updated for cell 4701.0
# dataframe updated for cell 4705.0
# dataframe updated for cell 4706.0
# dataframe updated for cell 4707.0
# dataframe updated for cell 4715.0
# dataframe updated for cell 4716.0
# dataframe updated for cell 4719.0
# dataframe updated for cell 4728.0
# dataframe updated for cell 4732.0
# dataframe updated for cell 4733.0
# dataframe updated for cell 4743.0
# dataframe updated for cell 4744.0
# dataframe updated for cell 4751.0
# dataframe updated for cell 4755.0
# dataframe updated for cell 4758.0
# dataframe updated for cell 4782.0
# dataframe updated for cell 4787.0
# dataframe updated for cell 4788.0
# dataframe updated for cell 4790.0
# dataframe updated for cell 4796.0
# dataframe updated for cell 4797.0
# dataframe updated for cell 4799.0
# dataframe updated for cell 4803.0
# dataframe updated for cell 4804.0
# dataframe updated for cell 4811.0
# dataframe updated for cell 4815.0
# dataframe updated for cell 4820.0
# dataframe updated for cell 4821.0
# dataframe updated for cell 4823.0
# dataframe updated for cell 4827.0
# dataframe updated for cell 4832.0
# dataframe updated for cell 4833.0
# dataframe updated for cell 4837.0
# dataframe updated for cell 4846.0
# dataframe updated for cell 4853.0
# dataframe updated for cell 4856.0
# dataframe updated for cell 4860.0
# dataframe updated for cell 4861.0
# dataframe updated for cell 4867.0
# dataframe updated for cell 4887.0
# dataframe updated for cell 4897.0
# dataframe updated for cell 4903.0
# dataframe updated for cell 4908.0
# dataframe updated for cell 4909.0
# dataframe updated for cell 4914.0
# dataframe updated for cell 4921.0
# dataframe updated for cell 4923.0
# dataframe updated for cell 4932.0
# dataframe updated for cell 4935.0
# dataframe updated for cell 4938.0
# dataframe updated for cell 4940.0
# dataframe updated for cell 4944.0
# dataframe updated for cell 4946.0
# dataframe updated for cell 4949.0
# dataframe updated for cell 4950.0
# dataframe updated for cell 4956.0
# dataframe updated for cell 4959.0
# dataframe updated for cell 4961.0
# dataframe updated for cell 4965.0
# dataframe updated for cell 4966.0
# dataframe updated for cell 4968.0
# dataframe updated for cell 4969.0
# dataframe updated for cell 4975.0
# dataframe updated for cell 4979.0
# dataframe updated for cell 4989.0
# dataframe updated for cell 4996.0
# dataframe updated for cell 4998.0
# dataframe updated for cell 5006.0
# dataframe updated for cell 5007.0
# dataframe updated for cell 5008.0
# dataframe updated for cell 5010.0
# dataframe updated for cell 5013.0
# dataframe updated for cell 5014.0
# dataframe updated for cell 5017.0
# dataframe updated for cell 5020.0
# dataframe updated for cell 5026.0
# dataframe updated for cell 5028.0
# dataframe updated for cell 5029.0
# dataframe updated for cell 5030.0
# dataframe updated for cell 5031.0
# dataframe updated for cell 5033.0
# dataframe updated for cell 5036.0
# dataframe updated for cell 5038.0
# dataframe updated for cell 5052.0
# dataframe updated for cell 5054.0
# dataframe updated for cell 5058.0
# dataframe updated for cell 5059.0
# dataframe updated for cell 5064.0
# dataframe updated for cell 5066.0
# dataframe updated for cell 5068.0
# dataframe updated for cell 5071.0
# dataframe updated for cell 5080.0
# dataframe updated for cell 5082.0
# dataframe updated for cell 5092.0
# dataframe updated for cell 5093.0
# dataframe updated for cell 5098.0
# dataframe updated for cell 5102.0
# dataframe updated for cell 5105.0
# dataframe updated for cell 5108.0
# dataframe updated for cell 5115.0
# dataframe updated for cell 5117.0
# dataframe updated for cell 5121.0
# dataframe updated for cell 5124.0
# dataframe updated for cell 5125.0
# dataframe updated for cell 5129.0
# dataframe updated for cell 5132.0
# dataframe updated for cell 5138.0
# dataframe updated for cell 5146.0
# dataframe updated for cell 5149.0
# dataframe updated for cell 5162.0
# dataframe updated for cell 5164.0
# dataframe updated for cell 5167.0
# dataframe updated for cell 5173.0
# dataframe updated for cell 5178.0
# dataframe updated for cell 5179.0
# dataframe updated for cell 5188.0
# dataframe updated for cell 5190.0
# dataframe updated for cell 5196.0
# dataframe updated for cell 5225.0
# dataframe updated for cell 5226.0
# dataframe updated for cell 5227.0
# dataframe updated for cell 5230.0
# dataframe updated for cell 5236.0
# dataframe updated for cell 5239.0
# dataframe updated for cell 5240.0
# dataframe updated for cell 5243.0
# dataframe updated for cell 5248.0
# dataframe updated for cell 5250.0
# dataframe updated for cell 5257.0
# dataframe updated for cell 5258.0
# dataframe updated for cell 5260.0
# dataframe updated for cell 5261.0
# dataframe updated for cell 5263.0
# dataframe updated for cell 5266.0
# dataframe updated for cell 5273.0
# dataframe updated for cell 5277.0
# dataframe updated for cell 5279.0
# dataframe updated for cell 5294.0
# dataframe updated for cell 5296.0
# dataframe updated for cell 5304.0
# dataframe updated for cell 5305.0
# dataframe updated for cell 5308.0
# dataframe updated for cell 5311.0
# dataframe updated for cell 5313.0
# dataframe updated for cell 5320.0
# dataframe updated for cell 5321.0
# dataframe updated for cell 5322.0
# dataframe updated for cell 5324.0
# dataframe updated for cell 5326.0
# dataframe updated for cell 5329.0
# dataframe updated for cell 5330.0
# dataframe updated for cell 5331.0
# dataframe updated for cell 5334.0
# dataframe updated for cell 5341.0
# dataframe updated for cell 5344.0
# dataframe updated for cell 5348.0
# dataframe updated for cell 5351.0
# dataframe updated for cell 5352.0
# dataframe updated for cell 5356.0
# dataframe updated for cell 5362.0
# dataframe updated for cell 5363.0
# dataframe updated for cell 5371.0
# dataframe updated for cell 5377.0
# dataframe updated for cell 5378.0
# dataframe updated for cell 5379.0
# dataframe updated for cell 5383.0
# dataframe updated for cell 5384.0
# dataframe updated for cell 5385.0
# dataframe updated for cell 5386.0
# dataframe updated for cell 5390.0
# dataframe updated for cell 5393.0
# dataframe updated for cell 5394.0
# dataframe updated for cell 5396.0
# dataframe updated for cell 5397.0
# dataframe updated for cell 5399.0
# dataframe updated for cell 5401.0
# dataframe updated for cell 5407.0
# dataframe updated for cell 5410.0
# dataframe updated for cell 5413.0
# dataframe updated for cell 5420.0
# dataframe updated for cell 5433.0
# dataframe updated for cell 5439.0
# dataframe updated for cell 5440.0
# dataframe updated for cell 5443.0
# dataframe updated for cell 5446.0
# dataframe updated for cell 5448.0
# dataframe updated for cell 5451.0
# dataframe updated for cell 5456.0
# dataframe updated for cell 5457.0
# dataframe updated for cell 5460.0
# dataframe updated for cell 5462.0
# dataframe updated for cell 5465.0
# dataframe updated for cell 5467.0
# dataframe updated for cell 5472.0
# dataframe updated for cell 5473.0
# dataframe updated for cell 5475.0
# dataframe updated for cell 5478.0
# dataframe updated for cell 5481.0
# dataframe updated for cell 5484.0
# dataframe updated for cell 5488.0
# dataframe updated for cell 5491.0
# dataframe updated for cell 5496.0
# dataframe updated for cell 5497.0
# dataframe updated for cell 5504.0
# dataframe updated for cell 5511.0
# dataframe updated for cell 5514.0
# dataframe updated for cell 5529.0
# dataframe updated for cell 5535.0
# dataframe updated for cell 5541.0
# dataframe updated for cell 5542.0
# dataframe updated for cell 5547.0
# dataframe updated for cell 5549.0
# dataframe updated for cell 5557.0
# dataframe updated for cell 5565.0
# dataframe updated for cell 5572.0
# dataframe updated for cell 5575.0
# dataframe updated for cell 5576.0
# dataframe updated for cell 5583.0
# dataframe updated for cell 5585.0
# dataframe updated for cell 5586.0
# dataframe updated for cell 5587.0
# dataframe updated for cell 5589.0
# dataframe updated for cell 5598.0
# dataframe updated for cell 5600.0
# dataframe updated for cell 5601.0
# dataframe updated for cell 5602.0
# dataframe updated for cell 5609.0
# dataframe updated for cell 5611.0
# dataframe updated for cell 5614.0
# dataframe updated for cell 5624.0
# dataframe updated for cell 5634.0
# dataframe updated for cell 5646.0
# dataframe updated for cell 5649.0
# dataframe updated for cell 5652.0
# dataframe updated for cell 5653.0
# dataframe updated for cell 5655.0
# dataframe updated for cell 5657.0
# dataframe updated for cell 5660.0
# dataframe updated for cell 5662.0
# dataframe updated for cell 5668.0
# dataframe updated for cell 5676.0
# dataframe updated for cell 5679.0
# dataframe updated for cell 5684.0
# dataframe updated for cell 5685.0
# dataframe updated for cell 5691.0
# dataframe updated for cell 5696.0
# dataframe updated for cell 5697.0
# dataframe updated for cell 5698.0
# dataframe updated for cell 5716.0
# dataframe updated for cell 5723.0
# dataframe updated for cell 5725.0
# dataframe updated for cell 5739.0
# dataframe updated for cell 5745.0
# dataframe updated for cell 5747.0
# dataframe updated for cell 5748.0
# dataframe updated for cell 5750.0
# dataframe updated for cell 5756.0
# dataframe updated for cell 5757.0
# dataframe updated for cell 5758.0
# dataframe updated for cell 5766.0
# dataframe updated for cell 5772.0
# dataframe updated for cell 5779.0
# dataframe updated for cell 5785.0
# dataframe updated for cell 5791.0
# dataframe updated for cell 5814.0
# dataframe updated for cell 5822.0
# dataframe updated for cell 5824.0
# dataframe updated for cell 5826.0
# dataframe updated for cell 5844.0
# dataframe updated for cell 5858.0
# dataframe updated for cell 5864.0
# dataframe updated for cell 5866.0
# dataframe updated for cell 5867.0
# dataframe updated for cell 5879.0
# dataframe updated for cell 5883.0
# dataframe updated for cell 5888.0
# dataframe updated for cell 5893.0
# dataframe updated for cell 5896.0
# dataframe updated for cell 5897.0
# ...
# dataframe updated for cell 206549.0
# dataframe updated for cell 206553.0
# dataframe updated for cell 206557.0
# dataframe updated for cell 206558.0
# dataframe updated for cell 206560.0
# dataframe updated for cell 206580.0
# dataframe updated for cell 206591.0
# dataframe updated for cell 206610.0
# dataframe updated for cell 206613.0
# dataframe updated for cell 206614.0
# dataframe updated for cell 206620.0
# dataframe updated for cell 206631.0
# dataframe updated for cell 206633.0
# dataframe updated for cell 206635.0
# dataframe updated for cell 206638.0
# dataframe updated for cell 206639.0
# dataframe updated for cell 206640.0
# dataframe updated for cell 206644.0
# dataframe updated for cell 206648.0
# dataframe updated for cell 206649.0
# dataframe updated for cell 206653.0
# dataframe updated for cell 206657.0
# dataframe updated for cell 206661.0
# dataframe updated for cell 206663.0
# dataframe updated for cell 206664.0
# dataframe updated for cell 206672.0
# dataframe updated for cell 206677.0
# dataframe updated for cell 206685.0
# dataframe updated for cell 206690.0
# dataframe updated for cell 206707.0
# dataframe updated for cell 206710.0
# dataframe updated for cell 206716.0
# dataframe updated for cell 206719.0
# dataframe updated for cell 206721.0
# dataframe updated for cell 206725.0
# dataframe updated for cell 206730.0
# dataframe updated for cell 206734.0
# dataframe updated for cell 206735.0
# dataframe updated for cell 206740.0
# dataframe updated for cell 206741.0
# dataframe updated for cell 206747.0
# dataframe updated for cell 206753.0
# dataframe updated for cell 206754.0
# dataframe updated for cell 206755.0
# dataframe updated for cell 206765.0
# dataframe updated for cell 206767.0
# dataframe updated for cell 206792.0
# dataframe updated for cell 206793.0
# dataframe updated for cell 206794.0
# dataframe updated for cell 206795.0
# dataframe updated for cell 206796.0
# dataframe updated for cell 206803.0
# dataframe updated for cell 206805.0
# dataframe updated for cell 206807.0
# dataframe updated for cell 206808.0
# dataframe updated for cell 206819.0
# dataframe updated for cell 206823.0
# dataframe updated for cell 206830.0
# dataframe updated for cell 206835.0
# dataframe updated for cell 206850.0
# dataframe updated for cell 206851.0
# dataframe updated for cell 206854.0
# dataframe updated for cell 206860.0
# dataframe updated for cell 206867.0
# dataframe updated for cell 206870.0
# dataframe updated for cell 206872.0
# dataframe updated for cell 206874.0
# dataframe updated for cell 206885.0
# dataframe updated for cell 206889.0
# dataframe updated for cell 206892.0
# dataframe updated for cell 206895.0
# dataframe updated for cell 206914.0
# dataframe updated for cell 206919.0
# dataframe updated for cell 206923.0
# dataframe updated for cell 206928.0
# dataframe updated for cell 206944.0
# dataframe updated for cell 206945.0
# dataframe updated for cell 206946.0
# dataframe updated for cell 206947.0
# dataframe updated for cell 206949.0
# dataframe updated for cell 206951.0
# dataframe updated for cell 206956.0
# dataframe updated for cell 206961.0
# dataframe updated for cell 206991.0
# dataframe updated for cell 206999.0
# dataframe updated for cell 207005.0
# dataframe updated for cell 207008.0
# dataframe updated for cell 207009.0
# dataframe updated for cell 207013.0
# dataframe updated for cell 207014.0
# dataframe updated for cell 207019.0
# dataframe updated for cell 207024.0
# dataframe updated for cell 207027.0
# dataframe updated for cell 207032.0
# dataframe updated for cell 207049.0
# dataframe updated for cell 207056.0
# dataframe updated for cell 207058.0
# dataframe updated for cell 207059.0
# dataframe updated for cell 207071.0
# dataframe updated for cell 207093.0
# dataframe updated for cell 207105.0
# dataframe updated for cell 207108.0
# dataframe updated for cell 207111.0
# dataframe updated for cell 207120.0
# dataframe updated for cell 207121.0
# dataframe updated for cell 207123.0
# dataframe updated for cell 207126.0
# dataframe updated for cell 207129.0
# dataframe updated for cell 207135.0
# dataframe updated for cell 207137.0
# dataframe updated for cell 207148.0
# dataframe updated for cell 207153.0
# dataframe updated for cell 207164.0
# dataframe updated for cell 207170.0
# dataframe updated for cell 207175.0
# dataframe updated for cell 207177.0
# dataframe updated for cell 207181.0
# dataframe updated for cell 207183.0
# dataframe updated for cell 207185.0
# dataframe updated for cell 207187.0
# dataframe updated for cell 207190.0
# dataframe updated for cell 207191.0
# dataframe updated for cell 207196.0
# dataframe updated for cell 207198.0
# dataframe updated for cell 207201.0
# dataframe updated for cell 207204.0
# dataframe updated for cell 207210.0
# dataframe updated for cell 207211.0
# dataframe updated for cell 207216.0
# dataframe updated for cell 207220.0
# dataframe updated for cell 207221.0
# dataframe updated for cell 207222.0
# dataframe updated for cell 207223.0
# dataframe updated for cell 207227.0
# dataframe updated for cell 207228.0
# dataframe updated for cell 207230.0
# dataframe updated for cell 207232.0
# dataframe updated for cell 207233.0
# dataframe updated for cell 207235.0
# dataframe updated for cell 207239.0
# dataframe updated for cell 207240.0
# dataframe updated for cell 207245.0
# dataframe updated for cell 207253.0
# dataframe updated for cell 207254.0
# dataframe updated for cell 207255.0
# dataframe updated for cell 207257.0
# dataframe updated for cell 207258.0
# dataframe updated for cell 207259.0
# dataframe updated for cell 207274.0
# dataframe updated for cell 207288.0
# dataframe updated for cell 207289.0
# dataframe updated for cell 207301.0
# dataframe updated for cell 207303.0
# dataframe updated for cell 207306.0
# dataframe updated for cell 207740.0
# dataframe updated for cell 207746.0
# dataframe updated for cell 207747.0
# dataframe updated for cell 207749.0
# dataframe updated for cell 207752.0
# dataframe updated for cell 207754.0
# dataframe updated for cell 207757.0
# dataframe updated for cell 207765.0
# dataframe updated for cell 207770.0
# dataframe updated for cell 207775.0
# dataframe updated for cell 207781.0
# dataframe updated for cell 207783.0
# dataframe updated for cell 207787.0
# dataframe updated for cell 207789.0
# dataframe updated for cell 207795.0
# dataframe updated for cell 207804.0
# dataframe updated for cell 207812.0
# dataframe updated for cell 207814.0
# dataframe updated for cell 207817.0
# dataframe updated for cell 207819.0
# dataframe updated for cell 207823.0
# dataframe updated for cell 207824.0
# dataframe updated for cell 207826.0
# dataframe updated for cell 207832.0
# dataframe updated for cell 207833.0
# dataframe updated for cell 207835.0
# dataframe updated for cell 207836.0
# dataframe updated for cell 207840.0
# dataframe updated for cell 207844.0
# dataframe updated for cell 207845.0
# dataframe updated for cell 207848.0
# dataframe updated for cell 207850.0
# dataframe updated for cell 207855.0
# dataframe updated for cell 207857.0
# dataframe updated for cell 207859.0
# dataframe updated for cell 207861.0
# dataframe updated for cell 207862.0
# dataframe updated for cell 207864.0
# dataframe updated for cell 207868.0
# dataframe updated for cell 207880.0
# dataframe updated for cell 207883.0
# dataframe updated for cell 207886.0
# dataframe updated for cell 207888.0
# dataframe updated for cell 207896.0
# dataframe updated for cell 207898.0
# dataframe updated for cell 207899.0
# dataframe updated for cell 207900.0
# dataframe updated for cell 207904.0
# dataframe updated for cell 207906.0
# dataframe updated for cell 207913.0
# dataframe updated for cell 207915.0
# dataframe updated for cell 207920.0
# dataframe updated for cell 207921.0
# dataframe updated for cell 207926.0
# dataframe updated for cell 207928.0
# dataframe updated for cell 207930.0
# dataframe updated for cell 207936.0
# dataframe updated for cell 207937.0
# dataframe updated for cell 207938.0
# dataframe updated for cell 207939.0
# dataframe updated for cell 207942.0
# dataframe updated for cell 207957.0
# dataframe updated for cell 207960.0
# dataframe updated for cell 207961.0
# dataframe updated for cell 207967.0
# dataframe updated for cell 207968.0
# dataframe updated for cell 207969.0
# dataframe updated for cell 207974.0
# dataframe updated for cell 207976.0
# dataframe updated for cell 207981.0
# dataframe updated for cell 207991.0
# dataframe updated for cell 207992.0
# dataframe updated for cell 207993.0
# dataframe updated for cell 207994.0
# dataframe updated for cell 207998.0
# dataframe updated for cell 208001.0
# dataframe updated for cell 208004.0
# dataframe updated for cell 208005.0
# dataframe updated for cell 208006.0
# dataframe updated for cell 208008.0
# dataframe updated for cell 208011.0
# dataframe updated for cell 208020.0
# dataframe updated for cell 208023.0
# dataframe updated for cell 208026.0
# dataframe updated for cell 208028.0
# dataframe updated for cell 208032.0
# dataframe updated for cell 208034.0
# dataframe updated for cell 208037.0
# dataframe updated for cell 208038.0
# dataframe updated for cell 208040.0
# dataframe updated for cell 208048.0
# dataframe updated for cell 208052.0
# dataframe updated for cell 208055.0
# dataframe updated for cell 208060.0
# dataframe updated for cell 208070.0
# dataframe updated for cell 208077.0
# dataframe updated for cell 208079.0
# dataframe updated for cell 208082.0
# dataframe updated for cell 208083.0
# dataframe updated for cell 208086.0
# dataframe updated for cell 208100.0
# dataframe updated for cell 208102.0
# dataframe updated for cell 208103.0
# dataframe updated for cell 208104.0
# dataframe updated for cell 208109.0
# dataframe updated for cell 208111.0
# dataframe updated for cell 208113.0
# dataframe updated for cell 208114.0
# dataframe updated for cell 208116.0
# dataframe updated for cell 208119.0
# dataframe updated for cell 208122.0
# dataframe updated for cell 208123.0
# dataframe updated for cell 208124.0
# dataframe updated for cell 208125.0
# dataframe updated for cell 208126.0
# dataframe updated for cell 208132.0
# dataframe updated for cell 208136.0
# dataframe updated for cell 208138.0
# dataframe updated for cell 208148.0
# dataframe updated for cell 208150.0
# dataframe updated for cell 208160.0
# dataframe updated for cell 208162.0
# dataframe updated for cell 208163.0
# dataframe updated for cell 208167.0
# dataframe updated for cell 208169.0
# dataframe updated for cell 208172.0
# dataframe updated for cell 208173.0
# dataframe updated for cell 208177.0
# dataframe updated for cell 208179.0
# dataframe updated for cell 208180.0
# dataframe updated for cell 208181.0
# dataframe updated for cell 208184.0
# dataframe updated for cell 208185.0
# dataframe updated for cell 208189.0
# dataframe updated for cell 208193.0
# dataframe updated for cell 208197.0
# dataframe updated for cell 208199.0
# dataframe updated for cell 208200.0
# dataframe updated for cell 208201.0
# dataframe updated for cell 208204.0
# dataframe updated for cell 208210.0
# dataframe updated for cell 208211.0
# dataframe updated for cell 208213.0
# dataframe updated for cell 208214.0
# dataframe updated for cell 208215.0
# dataframe updated for cell 208219.0
# dataframe updated for cell 208222.0
# dataframe updated for cell 208225.0
# dataframe updated for cell 208227.0
# dataframe updated for cell 208237.0
# dataframe updated for cell 208242.0
# dataframe updated for cell 208247.0
# dataframe updated for cell 208251.0
# dataframe updated for cell 208252.0
# dataframe updated for cell 208253.0
# dataframe updated for cell 208254.0
# dataframe updated for cell 208258.0
# dataframe updated for cell 208259.0
# dataframe updated for cell 208263.0
# dataframe updated for cell 208266.0
# dataframe updated for cell 208270.0
# dataframe updated for cell 208274.0
# dataframe updated for cell 208281.0
# dataframe updated for cell 208282.0
# dataframe updated for cell 208283.0
# dataframe updated for cell 208284.0
# dataframe updated for cell 208286.0
# dataframe updated for cell 208293.0
# dataframe updated for cell 208297.0
# dataframe updated for cell 208298.0
# dataframe updated for cell 208300.0
# dataframe updated for cell 208301.0
# dataframe updated for cell 208302.0
# dataframe updated for cell 208304.0
# dataframe updated for cell 208306.0
# dataframe updated for cell 208307.0
# dataframe updated for cell 208308.0
# dataframe updated for cell 208309.0
# dataframe updated for cell 208310.0
# dataframe updated for cell 208312.0
# dataframe updated for cell 208318.0
# dataframe updated for cell 208332.0
# dataframe updated for cell 208333.0
# dataframe updated for cell 208334.0
# dataframe updated for cell 208337.0
# dataframe updated for cell 208340.0
# dataframe updated for cell 208350.0
# dataframe updated for cell 208351.0
# dataframe updated for cell 208362.0
# dataframe updated for cell 208363.0
# dataframe updated for cell 208364.0
# dataframe updated for cell 208367.0
# dataframe updated for cell 208370.0
# dataframe updated for cell 208372.0
# dataframe updated for cell 208374.0

# %%
# returns a subset of cells with a lifetime larger or equal to min_hr  

# parameters: 
# min_hr : minimum of hoursthe cell should prevail (float)
# Tracks: pandas dataframe which is the output of the tobac trajectory linking 


def subset_tracks(Tracks, min_hr):
    durations= []
    long_cells = []
    i = 0 
    for c in np.unique(Tracks.cell):
        duration= (np.shape(Tracks.loc[Tracks.cell == c ])[0])* 0.5
        if duration >= min_hr:
            durations.append(duration)
            long_cells.append(c)
            
    for lc in long_cells:
        if i == 0:
            subset= Tracks.loc[Tracks.cell == lc ]
            i+=1 
        else:
            subset= subset.append(Tracks.loc[Tracks.cell == lc ])
            
    return subset

# %%
min_hr = 15 
subset= subset_tracks(Tracks, min_hr)

# %%
# Plot map with all individual tracks:
import cartopy.crs as ccrs
fig_map,ax_map=plt.subplots(figsize=(15,15),subplot_kw={'projection': ccrs.PlateCarree()})
ax_map=tobac.map_tracks(subset,axis_extent=axis_extent,axes=ax_map)
plt.savefig(plotdir+ '/tracks_15hr_TP.png')

# %% [markdown]
# Plotting the precipitation tracks with the longest lifetimes (here: all cells which last longer than 15 hours), we can see that these storms occur primarily in the south of the Tibetan Plateau.

# %% [markdown]
# # Compare nearest neighbor distance of features with different thresholds

# %%
# calculate minimum distance between neighboring features 
Features_gpm = calculate_nearestneighbordistance(Features, method_distance=None)
Features['min_distance'] /= 1000

# %%
# select minimum distance for features containing different thresholds (e.g. 1mm/hr vs. >=10 mm/hr)
heights_gpm, bins_gpm= tobac.nearestneighbordistance_histogram(Features_gpm.loc[Features_gpm.threshold_value == 1], bin_edges = np.linspace(0,2000,100))
heights10_gpm, bins10_gpm= tobac.nearestneighbordistance_histogram(Features_gpm.loc[Features_gpm.threshold_value >= 10], bin_edges = np.linspace(0,2000,100))

# %%
plt.style.use('seaborn')
plt.rcParams.update({'font.size': 30,
             'xtick.labelsize' : 30,'ytick.labelsize' : 30})
plt.figure(figsize=(15, 10))


height_gpm = heights_gpm/np.sum(heights_gpm)
height10_gpm = heights10_gpm/np.sum(heights10_gpm)


plt.bar(bins_gpm[:-1], height_gpm*100, width = 15,color='darkorange',linewidth= 2.5,  label= '1mm/hr')
plt.bar(bins10_gpm[:-1], height10_gpm*100, width = 15, edgecolor='darkblue', color= 'None', linewidth= 2.5,  label= '>= 10 mm/hr')


plt.ylim(0,20)
plt.xlim(0,800)
plt.xlabel('min distance (km)', fontsize= 25)
plt.ylabel('frequency (%)', fontsize = 25)
plt.legend(fontsize= 25)

# save figure to image file 
plt.savefig(plotdir + 'hist_nn_gpm_threshold_high_vs_low.png')

# %% [markdown]
# The histograms of nearest neighbor distances show that the most frequent minimum distances lie around 100 km, which indicates a rather sparse distribution of contigous precipitation areas (many isolated precipitation cells). Furthermore, it can be seen that features with the lowest threshold (1mm/hr) tend to be more close to another feature than features with thresholds equal to or larger than 10 mm/hr. This could indicate that meso-scale precipitation features with heavy rain rates tend to occur as rather isolated cells in the Tibetan Plateau region.

# %% [markdown]
# # calculate area with monthly feature and mask chunks

# %%
help(tobac.calculate_area)

# %% [markdown]
# Some functions (like tobac.calculate_area) require the segmentation mask as an input. Whereas the feature chunks can easily be merged together into one dataframe (see above), this is more difficult for the masks into one large iris cube, since the latter would be much larger in size for a high resolution dataset like GPM IMERG. To calculate for example the area for the cells, the best solution is to do it by month, just as the feature detection and segmentation.

# %%
data_dir = '/media/juli/Elements/GPM_IMERG_F_v05/GPM_finalrun/tobac/Save'

# %%
# import tracks for GPM 
savedir='/media/juli/Elements/GPM_IMERG_F_v05/GPM_finalrun/tobac/Save'
#file = savedir + '/Tracks_GPM_2014_2017_updatedframes.h5'
file = savedir + '/Tracks_GPM_2014-2017_v_precip.h5'
Tracks = pd.read_hdf(file, 'table')
Tracks['timestr']=pd.to_datetime(Tracks['timestr'],format='%Y-%m-%d %H:%M:%S')

# %%
# get file lists with monthly feature and mask chunks 
feature_chunks= glob.glob(data_dir + '/Features_Precip??????.h5')  
feature_chunks.sort()

mask_chunks= glob.glob(data_dir + '/Mask_Segmentation_precip??????.nc')  
mask_chunks.sort()

# %%
features = Tracks
for file in mask_chunks:
    print('calculating area for...', file)
    # read in  mask as iris cube 
    mask=iris.load_cube(file,'segmentation_mask')
    mask.attributes = None    
    features = tobac.calculate_area(features, mask, method_area= 'latlon')
    print('mean area for track features was...', np.nanmean(features.area.data))

# %%
np.max(np.unique(mask.data))
np.max(np.unique(features.index))

# %%
features['timestr']=pd.to_datetime(features['timestr'],format='%Y-%m-%d %H:%M:%S')
feat_select= features.loc[features['timestr'].dt.strftime('%Y-%m') == '2014-04']
feat_select

# %%
# use contraint time to select specific time frame! 
c = 0 
from iris import Constraint
for time_i, features_i in Tracks.groupby('time'):
    constraint_time = Constraint(time= time_i)
    mask_i= mask.extract(constraint_time)
    print(time_i, np.shape(features_i))

# %%
for file in feature_chunks:
    month = file[76:82]
    print('calculating area for...', month)
    # read in features as pandas dataframe
    features = pd.read_hdf(file, 'table')
    if month  == '201403':
        df = features 
    # read in corresponding mask as iris cube 
    m=  data_dir + '/Mask_Segmentation_precip'+ month +'.nc'
    mask=iris.load_cube(m,'segmentation_mask')
    mask.attributes = None    
    features = tobac.calculate_area(features, mask, method_area= 'latlon')
    df = df.append(features)

# %% [markdown]
# ## Track stats

# %%
import pandas as pd
gpm= '/media/juli/Data/third_pole/satellite_data/gpm_v06/Save/track_statistics_gpm.h5'
gpm_cells= pd.read_hdf(gpm, 'table')
cnrr= '/media/juli/Data/third_pole/mcs_tracking/CNRR/Save/track_statistics_cnrr.h5'
cnrr_cells= pd.read_hdf(cnrr, 'table')
era = '/media/juli/Elements/ERA5/monthly/Save/track_statistics_era5.h5'
mcs = pd.read_hdf(era, 'table')

# %% [markdown]
# ## choose CNRR MCS

# %%
cnrr_intense= cnrr_cells.sort_values(by = 'features>5mm', ascending = False)[0:2000]

# %%
cnrr_long= cnrr_cells.sort_values(by = 'lifetime', ascending = False)[0:2000]

# %%
cnrr_large= cnrr_cells.sort_values(by = 'mean_area', ascending = False)[0:1000]

# %%
la= cnrr_intense.id.values
lo = cnrr_long.id.values

# %%
count = 0 
for i in la:
    if i in lo:
        count+= 1

# %%
count
# Out:
# 604

# %%
np.mean(cnrr_long.v.values)
# Out:
# 4.456323926015912

# %%
np.sqrt(np.max(cnrr_large.mean_area.values) / np.pi)
# Out:
# 473.1762432518091

# %%
np.max(cnrr_intense['features>5mm'].values)
# Out:
# 32.0

# %%
cells= gpm_cells
cells = cells[cells['features>5mm'] > 5]
cells =cells.sort_values(by = 'total_precip', ascending = False)[0:2000]

cells_cnrr= cnrr_cells
cells_cnrr = cells_cnrr[cells_cnrr['features>5mm'] > 5]
cells_cnrr =cells_cnrr.sort_values(by = 'total_precip', ascending = False)[0:2000]

cells_era= mcs
cells_era = cells_era[cells_era['features>5mm'] > 5]
cells_era =cells_era.sort_values(by = 'total_precip', ascending = False)[0:2000]

# %%
# large cells

gpm = (cells.total_precip.values*(14136.0/1000)* (14136.0/1000)  ) / (cells.mean_area.values)
i = (cells_cnrr.total_precip.values*(18000.0/1000)* (14136.0/1000) )/ (cells_cnrr.mean_area.values)
era= ((cells_era.total_precip.values*2)* dxy * dxy) / (cells_era.mean_area.values/1000000)

hist, edges= np.histogram(gpm,bins = 100, density = True, range = (np.min(era),np.max(gpm)))
hist_cnrr, edges= np.histogram(i, bins = 100, normed = True,  range = (np.min(era),np.max(gpm)))
hist_era, edges= np.histogram(era, bins = 100, density = True, range = (np.min(era),np.max(gpm)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-eecedb599568> in <module>
#       3 gpm = (cells.total_precip.values*(14136.0/1000)* (14136.0/1000)  ) / (cells.mean_area.values)
#       4 i = (cells_cnrr.total_precip.values*(18000.0/1000)* (14136.0/1000) )/ (cells_cnrr.mean_area.values)
# ----> 5 era= ((cells_era.total_precip.values*2)* dxy * dxy) / (cells_era.mean_area.values/1000000)
#       6
#       7 hist, edges= np.histogram(gpm,bins = 100, density = True, range = (np.min(era),np.max(gpm)))
#
# NameError: name 'dxy' is not defined

# %%
gpm = cells.lifetime.values
i = cells_cnrr.lifetime.values
era= cells_era.lifetime.values*2

hist, edges= np.histogram(gpm,bins = 50, density = True, range = (np.min(era),np.max(era)))
hist_cnrr, edges= np.histogram(i, bins = 50, normed = True,  range = (np.min(era),np.max(era)))
hist_era, edges= np.histogram(era, bins = 50, density = True, range = (np.min(era),np.max(era)))

# %%
gpm = np.sqrt(cells.mean_area.values/ np.pi)
cells['eq_rad'] = gpm
eq_rad = np.sqrt(cells_cnrr.mean_area.values/ np.pi)
cells_cnrr['eq_rad'] = eq_rad
meanarea= cells_era.mean_area.values/1000000
eq_rad = np.sqrt(meanarea/ np.pi)
cells_era['eq_rad'] = eq_rad

# %%
gpm = np.sqrt(gpm_cells.max_area.values/ np.pi)
gpm_cells['eq_rad'] = gpm
eq_rad = np.sqrt(cnrr_cells.max_area.values/ np.pi)
cnrr_cells['eq_rad'] = eq_rad
meanarea= mcs.max_area.values/1000000
eq_rad = np.sqrt(meanarea/ np.pi)
mcs['eq_rad'] = eq_rad

# %%
# all tracks 
gpm = gpm_cells.lifetime.values 
i = cnrr_cells.lifetime.values
era= mcs.lifetime.values

hist, edges= np.histogram(gpm,bins = 30, density = True, range = (np.min(i),np.max(i)))
hist_cnrr, edges= np.histogram(i, bins = 30, normed = True,  range = (np.min(i),np.max(i)))
hist_era, edges= np.histogram(era, bins = 30, density = True, range = (np.min(i),np.max(i)))

# %%
# comparison of systems 


a= np.sqrt(cnrr_large.max_area.values / np.pi)
i = np.sqrt(cnrr_intense.max_area.values / np.pi)
hist, edges= np.histogram(a,bins = 30, density = True, range = (np.min(i),np.max(i)))
hist_cnrr, edges= np.histogram(i, bins =30, normed = True,  range = (np.min(i),np.max(i)))

# %%
# Lifetimes of tracked features:

plt.style.use('seaborn')
plt.rcParams.update({'font.size': 25,
                     'xtick.labelsize' : 25,
                     'ytick.labelsize' : 25})



#plt.figure(figsize=(20, 17))
fig_lifetime, ax_lifetime= plt.subplots(figsize= (15,10))


xaxis = edges[:-1]


plt.bar(xaxis, hist/np.nansum(hist)*100, width= 5,color='darkorange', label= 'large')
plt.bar(xaxis, hist_cnrr/np.nansum(hist_cnrr)*100, width= 5, edgecolor='darkblue', color= 'None', linewidth= 3.5, label= 'intense' )

ax_lifetime.set_xlabel('average propagation speed (m/s)', fontsize= 30)
ax_lifetime.set_ylabel('Frequency %', fontsize = 30)
plt.legend(fontsize= 35)



# save figure to image file 
plt.savefig('/media/juli/Data/third_pole/mcs_tracking/tobac_plots/cnrr_large_vs_intense1000_meaneqr.png')

# %%
print (np.median(cells.total_precip.values), np.median(cells_cnrr.total_precip.values), np.median(cells_era.total_precip.values*2))
# Out:
# 8009.518128395081 5395.956809997559 2283.558378061998

# %% [markdown]
# ## Thresholds

# %%
# import tracks for CNRR 
savedir='/media/juli/Data/third_pole/mcs_tracking/CNRR/Save'
file = savedir + '/Tracks_CNRR_2006-2016_storms.h5'
Tracks_cnrr = pd.read_hdf(file, 'table')
Tracks_cnrr['timestr']=pd.to_datetime(Tracks_cnrr['timestr'],format='%Y-%m-%d %H:%M:%S')

# %%
# import tracks for GPM 
savedir='/media/juli/Data/third_pole/satellite_data/gpm_v06/Save'
file = savedir + '/Tracks_GPM_2006_2016_storms_tpflag.h5'
Tracks_gpm = pd.read_hdf(file, 'table')
Tracks_gpm['timestr']=pd.to_datetime(Tracks_gpm['timestr'],format='%Y-%m-%d %H:%M:%S')

# %%
t= [1,2,3,4,5,7,10,15]
t= np.array(t)

# %%
gpm= np.array(())
for t in np.unique(Tracks_gpm.threshold_value):
    gpm = np.append(gpm, np.shape(Tracks_gpm[Tracks_gpm.threshold_value == t])[0] / np.shape(Tracks_gpm)[0]*100)

# %%
cnrr= np.array(())
for t in np.unique(Tracks_cnrr.threshold_value):
    cnrr = np.append(cnrr, np.shape(Tracks_cnrr[Tracks_cnrr.threshold_value == t])[0] / np.shape(Tracks_cnrr)[0]*100)

# %%
Tracks =Tracks_era

# %%
era= np.array(())
for t in np.unique(Tracks.threshold_value):
    era = np.append(era, np.shape(Tracks[Tracks.threshold_value == t])[0] / np.shape(Tracks)[0]*100)

# %%
# Lifetimes of tracked features:

plt.style.use('seaborn')
plt.rcParams.update({'font.size': 25,
                     'xtick.labelsize' : 25,
                     'ytick.labelsize' : 25})

#plt.figure(figsize=(20, 17))
fig_lifetime, ax_lifetime= plt.subplots(figsize= (15,10))

xaxis = np.arange(8)

plt.bar(xaxis + 0.00, gpm, width=0.25, color='darkorange', label='GPM')
plt.bar(xaxis + 0.25, cnrr, width = 0.25, color='darkblue',  label= 'CNRR')
plt.bar(xaxis + 0.50, era, width = 0.25, color='gold',  label= 'ERA5')

ax_lifetime.set_xlabel('threshold (mm/hr)', fontsize= 30)
ax_lifetime.set_ylabel('Frequency (%)', fontsize = 30)
labels = ['1', '2', '3', '4', '5', '7', '10', '15']
plt.xticks(xaxis, labels)
plt.legend(fontsize= 30)

# save figure to image file 
plt.savefig('/media/juli/Data/third_pole/mcs_tracking/tobac_plots/threshold_freq_CNRR_GPM_ERA_20062016.png')

# %% [markdown]
# # Multiple regression for total precip

# %% [markdown]
# ## standardization

# %%
cell= cells_gpm
dx= 14136.0/1000

# %%
cell= cells_era
dx= 40000.0

# %%
cell= cells_cnrr
dx= 18000.0/1000

# %%
y= cell.total_precip.values - np.nanmean(cell.total_precip.values) / np.nanstd(cell.total_precip.values)
pixels= cell.mean_area.values / (dx*dx)
x1= (pixels- np.nanmean(pixels)) / np.nanstd(pixels)
x2= (cell.mean_rr.values- np.nanmean(cell.mean_rr.values)) / np.nanstd(cell.mean_rr.values)
x3= (cell.max_rr.values- np.nanmean(cell.max_rr.values)) / np.nanstd(cell.max_rr.values)
x4= (cell.lifetime.values- np.nanmean(cell.lifetime.values)) / np.nanstd(cell.lifetime.values)

# %%
y= cell.total_precip.values
x2= cell.mean_rr.values -np.nanmean( cell.mean_rr.values)
x3= cell.max_rr.values - np.nanmean( cell.max_rr.values)
x4= cell.lifetime.values - np.nanmean( cell.lifetime.values)

# %%
from sklearn.linear_model import LinearRegression

import statsmodels.api as sm
from scipy.stats.mstats import zscore

print(sm.OLS(zscore(y), zscore(x1)).fit().summary())
print(sm.OLS(zscore(y), zscore(x2)).fit().summary())
print(sm.OLS(zscore(y), zscore(x3)).fit().summary())
print(sm.OLS(zscore(y), zscore(x4)).fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.418
# Model:                            OLS   Adj. R-squared (uncentered):              0.418
# Method:                 Least Squares   F-statistic:                              1435.
# Date:                Sun, 01 Sep 2019   Prob (F-statistic):                   3.88e-237
# Time:                        17:09:16   Log-Likelihood:                         -2296.8
# No. Observations:                2000   AIC:                                      4596.
# Df Residuals:                    1999   BIC:                                      4601.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6464      0.017     37.880      0.000       0.613       0.680
# ==============================================================================
# Omnibus:                     1825.004   Durbin-Watson:                   0.685
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           156456.355
# Skew:                           3.943   Prob(JB):                         0.00
# Kurtosis:                      45.606   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.069
# Model:                            OLS   Adj. R-squared (uncentered):              0.069
# Method:                 Least Squares   F-statistic:                              148.5
# Date:                Sun, 01 Sep 2019   Prob (F-statistic):                    5.22e-33
# Time:                        17:09:16   Log-Likelihood:                         -2766.2
# No. Observations:                2000   AIC:                                      5534.
# Df Residuals:                    1999   BIC:                                      5540.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.2630      0.022     12.187      0.000       0.221       0.305
# ==============================================================================
# Omnibus:                     1768.790   Durbin-Watson:                   0.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            84980.955
# Skew:                           3.969   Prob(JB):                         0.00
# Kurtosis:                      33.931   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.221
# Model:                            OLS   Adj. R-squared (uncentered):              0.221
# Method:                 Least Squares   F-statistic:                              566.9
# Date:                Sun, 01 Sep 2019   Prob (F-statistic):                   1.63e-110
# Time:                        17:09:16   Log-Likelihood:                         -2588.2
# No. Observations:                2000   AIC:                                      5178.
# Df Residuals:                    1999   BIC:                                      5184.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4700      0.020     23.809      0.000       0.431       0.509
# ==============================================================================
# Omnibus:                     1815.597   Durbin-Watson:                   0.407
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           114838.122
# Skew:                           4.030   Prob(JB):                         0.00
# Kurtosis:                      39.237   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.432
# Model:                            OLS   Adj. R-squared (uncentered):              0.432
# Method:                 Least Squares   F-statistic:                              1521.
# Date:                Sun, 01 Sep 2019   Prob (F-statistic):                   6.42e-248
# Time:                        17:09:16   Log-Likelihood:                         -2272.0
# No. Observations:                2000   AIC:                                      4546.
# Df Residuals:                    1999   BIC:                                      4552.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.6574      0.017     39.002      0.000       0.624       0.690
# ==============================================================================
# Omnibus:                     2011.890   Durbin-Watson:                   0.787
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           174146.914
# Skew:                           4.670   Prob(JB):                         0.00
# Kurtosis:                      47.749   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ##  Plot track densities

# %%
# read in empty CNRR grid 

cnrr = '/media/juli/Data/third_pole/CNRR/data/summermean_2006_2016.nc4'
ds = Dataset(cnrr)
lat= np.array(ds['LAT'])
lon = np.array(ds['LON'])

# %%
# import tracks for CNRR 
savedir='/media/juli/Data/third_pole/mcs_tracking/CNRR/Save'
file = savedir + '/Tracks_CNRR_2006-2016_storms.h5'
Tracks = pd.read_hdf(file, 'table')

# %%
# subset trackdataframe cnrr_tracks, based on cnrr_intense/cnrr_large and extract only lats and lons 

i = 0 
for c in cnrr_intense.id.values:
    print(c)
    if i == 0:
        df= Tracks.loc[Tracks.cell == c ]
        i+=1 
    else:
        df= df.append(Tracks.loc[Tracks.cell == c ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-ad86f74ba38b> in <module>
#       2
#       3 i = 0
# ----> 4 for c in cnrr_intense.id.values:
#       5     print(c)
#       6     if i == 0:
#
# NameError: name 'cnrr_intense' is not defined

# %%
import xarray as xr
count= np.zeros((141,201))
data = xr.DataArray(count)
data.to_netcdf(path= '/media/juli/Data/third_pole/CNRR/data/density_matrix.nc')

# %%
def geo_idx(in_coord, coord_arr):
    geo_idx = (np.abs(coord_arr - in_coord)).argmin()
    return geo_idx

# %%
in_lat = track_lats[0]
in_lon = track_lons[0]
lat_idx = geo_idx(in_lat, lat.flatten())
lon_idx = geo_idx(in_lon, lon.flatten())
print(in_lat, lat_idx, in_lon, lon_idx)
# Out:
# 20.716601603410062 48 74.84557075310028 6242

# %%
#        '2016-09-24 13:00:00', '2016-09-26 13:00:00',
#        '2016-09-27 15:00:00', '2016-10-08 14:00:00',
#        '2016-10-09 20:00:00', '2016-10-23 00:00:00'], dtype=object)

# %%
np.sum(count[count > 0] )
# Out:
# 94957.0

# %%
np.

# %%
np.mean(cnrr_intense.max_rr.values)
# Out:
# 96.4943217740059

# %%
plt.scatter(cnrr_intense.max_area, cnrr_intense.v)

# %%
cnrr_intense[cnrr_intense.id ==  367104.0]
# Out:
#            id            init_time  total_precip   mean_rr      max_rr  \
# 42564  367104  2013-07-25 05:00:00  34588.455662  5.782097  128.841248
#
#        lifetime         v      max_area      mean_area    total_area  \
# 42564      35.0  3.839615  29865.497159  365282.834688  1.045292e+06
#
#        features>5mm
# 42564          32.0

# %%
df= Tracks

# %%
# loop through grid cells and compare lat and lon table 

track_lats= df.latitude.values
track_lons= df.longitude.values
count= np.zeros((141,201))

for idx,row in enumerate(count):
    for coli, v in enumerate(row):
        lat1 = lat[idx, coli]
        lon1 = lon[idx, coli]
        
        lat2= lat1 + 0.3
        lon2= lon1 + 0.3 
        
        for i, x in enumerate(track_lats):
            y = track_lons[i]
            if x >= lat1 and x < lat2 and y >= lon1 and y < lon2:
                count[idx, coli] +=1 
    print('density matrix updated.', np.shape(count[count > 0]) ) 
        
        
data = xr.DataArray(count)
data.to_netcdf(path= '/media/juli/Data/third_pole/CNRR/data/density_matrix_cnrrall.nc')
print('netcdf file saved')
# Out:
# density matrix updated. (200,)

# %%
    

data = xr.DataArray(count)
data.to_netcdf(path= '/media/juli/Data/third_pole/CNRR/data/density_matrix.nc')
print('netcdf file saved')
# Out:
# netcdf file saved

# %%
import matplotlib.pyplot as plt
import cartopy
from mpl_toolkits.basemap import Basemap
import matplotlib.colors as colors

# %%
count[count> 0 ].shape
# Out:
# (9186,)

# %%
# plot densities with pcolormesh


plt.figure(figsize=(20, 9))


cmap = plt.cm.get_cmap('viridis_r')

m = Basemap(projection='cyl', llcrnrlat=25.95,urcrnrlat=44.95, llcrnrlon=70.05, urcrnrlon=105.05,  resolution = 'c')

xi,yi = m(lon,lat)
cs = m.pcolormesh(xi,yi, count, cmap='bone_r', vmin= 1, vmax = 30 )
cmap.set_under(color='white')

xlabels=[70, 80, 90, 100]
ylabels= [ 27, 30, 35, 40, 45]

plt.xticks([70, 80,90, 100], xlabels, fontsize=25)
plt.yticks([27,30, 35, 40, 45],ylabels, fontsize=25)
plt.xlabel('Lon $^\circ$E',  fontsize=30)
plt.ylabel('Lat $^\circ$N',  fontsize=30)

# Plot TP boundary polyline from shapefile 
shapefile='/media/juli/Data/master_thesis/Master_thesis/data/DBATP/DBATP'
TP_bound=m.readshapefile(shapefile, 'boundary', color='black', linewidth=2.5)


cbar = plt.colorbar(extend= 'max')
cbar.set_label(' #tracks', fontsize= 30)


plt.rcParams.update({'font.size': 25})
plt.tight_layout()


plt.savefig('/media/juli/Elements/comparison/cnrr_trackdensity_most_intense.png')
# Out:
# /home/juli/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   if __name__ == '__main__':
# /home/juli/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
