# %% [markdown]
# # Example tracking WRF 9km

# %%
from pathlib import Path
import numpy as np
import tobac 
import pandas as pd 
import iris 
import xarray as xr 
import matplotlib.pyplot as plt
# import parameters for feature detection and segmentation
from parameters import parameters_features, parameters_segmentation, dxy, dt

import warnings  
warnings.filterwarnings("ignore")

# %%
savedir = Path('out/')
file = 'WRFOut_TP9km_HourlyP_2016_08.nc'
Precip=iris.load_cube(file, 'Prep')
xprecip=xr.open_dataset(file)
Precip
# Out:
# <iris 'Cube' of Prep / (mm) (time: 744; south_north: 549; west_east: 729)>

# %% [markdown]
# ## Feature detection

# %%
Features= tobac.feature_detection_multithreshold(Precip,dxy,**parameters_features) 
Features.to_hdf(os.path.join(savedir,'Features_201708.h5'),'table')

# %% [markdown]
# ## Segmentation

# %%
Mask, Features_cells = tobac.segmentation_2D(Features, Precip, dxy, **parameters_segmentation)

# %%
iris.save([Mask], savedir/ 'Mask_Segmentation_201708.nc',zlib=True,complevel=4)                
Features_cells.to_hdf(savedir/'Features_cells_201708.h5','table')

# %% [markdown]
# ## Basic statistics of results

# %%
import seaborn as sns 
sns.set()

frequencies, bins = np.histogram(Features_cells.threshold_value.values, bins = np.arange(3,11))

plt.bar(bins[:-1], frequencies, color = 'darkblue')
plt.xlabel('precipitation threshold')
plt.ylabel('number of rain cells')
# Out:
# Text(0, 0.5, 'number of rain cells')

# %%
frequencies, bins = np.histogram(Features_cells.ncells.values, bins = np.arange(100,1500,50))

plt.bar(bins[:-1], frequencies, width = 45, color = 'darkblue')
plt.xlabel('area [number of grid cells]')
plt.ylabel('number of rain cells')
# Out:
# Text(0, 0.5, 'number of rain cells')

# %%
# rainfall amount
plt.figure(figsize=(9,5))
precipsum= np.nansum(xprecip.Prep.values, axis = 0)
plt.pcolormesh(precipsum, cmap = 'Blues', vmin = 0, vmax = 1000)

cbar=plt.colorbar()
cbar.ax.set_ylabel('total amount of monthly rainfall [mm]')
plt.show()

# %%
# track density 
plt.figure(figsize=(10,6))
mask= Mask.data
mask[mask > 0] = 1
masksum= np.nansum(mask, axis = 0)
plt.pcolormesh(masksum, cmap = 'viridis')
cbar=plt.colorbar()
cbar.ax.set_ylabel('track density')
plt.show()
